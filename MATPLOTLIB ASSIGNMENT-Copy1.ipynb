# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house=pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\research\HOUSING CSV FILE.csv")

# %%
house.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
house.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
house['waterfront'].value_counts()#.plot.barh()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
house['view'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='view'>

# %%
1. Which of the following libraries should be imported for creating charts in python?
a. Pandas
b. Random
c. Math
d. Matplotlib

#Ans: d. Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,6))
house.groupby(['grade']).size().plot.bar()
# Out:
# <AxesSubplot:xlabel='grade'>

# %%
house['grade'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='grade'>

# %%
2. How to visualize the correlation pattern in the dataset?
a. Histogram
b. Bar plot
c. Scatterplot
d. Heatmap

#Ans: c. Scatterplot

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=house['sqft_living'],y=house['sqft_above'], hue=house['waterfront'])
house['sqft_living'].corr(house['sqft_above'])
# Out:
# 0.876596598681317

# %%
3. Which function can we use for plotting the boxplot?
a. sns.box()
b. plt.bplot()
c. sns.boxplot()
d. pl.boxplt()

#Ans: c. sns.boxplot()
# Out:
# Object `boxplot` not found.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 get_ipython().run_line_magic('pinfo', 'boxplot')
# ----> 2 a. sns.box()
#       3 b. plt.bplot()
#       4 c. sns.boxplot()
#
# NameError: name 'a' is not defined

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x='bathrooms',y='sqft_above',data=house)
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='sqft_above'>

# %%
4. What insights can we extract from the boxplot?
a. 2nd quartile
b. 1st quadrille
c. 3rd quartile
d. All of the above

#Ans: d. All of the above
# Out:
#   Input In [68]
#     a. 2nd quartile
#        ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(8,8))
sns.boxplot(y='sqft_above',data=house)
# Out:
# <AxesSubplot:ylabel='sqft_above'>

# %%
5. Which visualization is not part of matplotlib?
a. Table plot
b. Area plot
c. Violin plot
d. All of the above

#Ans: a. Table plot

# %%
6. From which visualization we can find the median/mean value of
the data?
a. Bar plot
b. Boxplot
c. Violin plot
d. All of the above

#Ans: d. All of the above

# %%
7. Which of the following is correct?
a. plt.scatter(data[‘gender’],data[‘age’])
b. plt.boxpt(data[‘gender’],data[‘age’])
c. plt.scatter(data[‘salary’],data[‘age’])
d. None of the above

# Ans:c. plt.scatter(data[‘salary’],data[‘age’])

# %%
plt.scatter(house['bedrooms'],house['grade'])

# %%
8. What error you will get after executing the below
code: data.box('bedrooms','grade')
a. Attribute error
b. Syntax error
c. Runtime error
d. None of the above

#Ans: a. Attribute error

# %%
house.box('bedrooms','grade')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 house.box('bedrooms','grade')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'box'

# %%
9. Which of the following code you can use for plotting the
pie chart:
a. plt.pie(x)
b. sns.pie(x)
c. Both of the above
d. None of the above

# Ans: a. plt.pie(x)

# %%
x=house['view'].value_counts()
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x20c672f4400>,
#   <matplotlib.patches.Wedge at 0x20c672f47c0>,
#   <matplotlib.patches.Wedge at 0x20c672f4ca0>,
#   <matplotlib.patches.Wedge at 0x20c673001c0>,
#   <matplotlib.patches.Wedge at 0x20c673006a0>],
#  [Text(-1.0479897705728087, 0.33424159043235785, ''),
#   Text(0.9769630759838076, -0.5055127576671604, ''),
#   Text(1.0620653331221095, -0.2863865013931748, ''),
#   Text(1.0890841991976294, -0.15458203989486735, ''),
#   Text(1.0988176827528706, -0.0509872539916758, '')])

# %%
10. What is the correct way of plotting violin plot?
a. sns.violinplot(data=data, y = 'price',x 'waterfront')
b. sns.violin(data=data, y = 'price',x = 'waterfront')
c. plt.violinplot(data=data, y = 'price',x='waterfront')
d. All of the above

#Ans:a. sns.violinplot(data=data, y = 'price',x 'waterfront')

# %%
sns.violinplot(data=house, y = 'price',x = 'waterfront')
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
11. Select the incorrect syntax:
a. plt.figsize()
b. plt.figtext()
c. plt.figpic()
d. Both A and C

#Ans: d. Both A and C

# %%
12. What inference you can extract from the below
graph:
    
    
    
    a. The cheapest house is having 3 floors.
b. The costliest house is having 2.5 floors.
c. The maximum number of houses are having 1 floor
only
d. All of the above

# Ans: d. All of the above

# %%
plt.xlabel('floors')
plt.ylabel('price of the houses (lacs)')
plt.scatter(house['floors'],house['price'])

# %%
13. Which of the following statements are correct with respect to the
below image:
a. The maximum number of houses have grades of either 7 or 8.
b. Around 2000 houses are having grades between 6 and 7.
c. Both of the above.
d. None of the above.

#Ans: c. Both of the above.

# %%
fig, ax = plt.subplots(figsize =(6, 6))
ax.hist('grade', bins =10,data=house)
# Out:
# (array([1.0000e+00, 3.0000e+00, 2.9000e+01, 2.4200e+02, 2.0380e+03,
#         1.5049e+04, 2.6150e+03, 1.1340e+03, 3.9900e+02, 1.0300e+02]),
#  array([ 1. ,  2.2,  3.4,  4.6,  5.8,  7. ,  8.2,  9.4, 10.6, 11.8, 13. ]),
#  <BarContainer object of 10 artists>)

# %%
14. Which of the following statements is/are correct with respect to the below image:
a. The average-priced house has grades between 10 and 12.
b. The costliest house is having a grade below 10.
c. As the price is getting higher, grades are also getting higher.
d. The average-priced house is having average grades.

#Ans: c. As the price is getting higher, grades are also getting higher.

# %%
plt.xlabel('Price')
plt.ylabel('Grades')
plt.scatter(house['price'],house['grade'])

# %%
#fig, ax = plt.subplots(figsize =(8, 6))
#ax.hist(x='price',y='grade',data=house)
sns.set(style="white")
f, ax = plt.subplots(figsize=(10, 8))
fig = sns.boxplot(x='grade', y="price", data=house, color="m")
fig.axis(ymin=0, ymax=7000000);

# %%
15. Which statement is correct with respect to the below
image:
a. The maximum number of houses are not having any view.
b. Around 300 houses are having only one view.
c. The 4th category is having the least count of houses.
d. All of the above.

#Ans: d. All of the above.

# %%
plt.figure(figsize=(9,6))
house.groupby(['view']).size().plot.bar()
# Out:
# <AxesSubplot:xlabel='view'>

# %%
16. Which of the following statements are correct with respect to the below image:
a. All categories of floors are having outliers.
b. We can handle the outliers by replacing them with the mean of the
column. c. We can handle the outliers by replacing them with the mode of
the column.
a. Only a is correct
b. a&c are correct
c. b&c are correct
d. All statements are correct.

# Ans: a. Only a is correct

# %%
plt.xlabel('floors')
plt.ylabel('Number of bedrooms')
sns.boxplot(house['floors'],house['bedrooms'])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='floors', ylabel='bedrooms'>

# %%
17. Which statement is correct with respect to the below image:

a. Maximum houses have zip codes between 98100 and 98125.
b. A Smaller number of houses have zip codes between 98075 and 98100.
c. The houses that are having zip codes between 98000 and 98050 are
having the costliest houses.
d. All of the above.

#Ans: d. All of the above.

# %%
fig, ax = plt.subplots(figsize =(8, 6))
ax.hist('zipcode', bins =10,data=house)
# Out:
# (array([2857., 4384., 3345., 1699.,  351., 4259., 1811., 1134., 1040.,
#          733.]),
#  array([98001. , 98020.8, 98040.6, 98060.4, 98080.2, 98100. , 98119.8,
#         98139.6, 98159.4, 98179.2, 98199. ]),
#  <BarContainer object of 10 artists>)

# %%
18. Which of the following statements is/are correct with respect to the below image:
    a. If the price is getting higher, the area of sqft_living is also
increasing.
b. If the price is getting lower, the area of sqft_living is decreasing.
c. The costliest house has the maximum sqft of living area.
A. A and B
B. A and C
C. B and C
D. Only A
E. Only B
F. Only C

#Ans: F. Only C

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=house['sqft_living'],y=house['price'])
house['sqft_living'].corr(house['price'])
# Out:
# 0.702035052433683

# %%
19. Which of the following statements are correct with respect to the below image:
    a. The interquartile range for the 4th category of view is the highest among
the rest of the views.
b. The houses that are having no view, are having a high probability of having
a cheap house.
c. Both of the above.
d. None of the above.

#Ans: c. Both of the above.

# %%
plt.figure(figsize=(8,8))
sns.violinplot(house['view'],house['price'])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='view', ylabel='price'>

# %%
20. Which of the following statements is/are correct with respect to the below image:
    a. The average area of square foot living in 3 number floors is very close to its
1st quartile value.
b. The 1st quartile value and the minimum square feet of living space are
almost the same.
c. Each category of floors are having outliers.
d. All of the above.

#Ans: d. All of the above.

# %%
sns.boxplot(x='floors',y='sqft_living',data=house,notch=False)
# Out:
# <AxesSubplot:xlabel='floors', ylabel='sqft_living'>

# %%
21. Which of the following statements is/are correct with respect to the below image:
    a. If the condition is increasing, the price of the house is also increasing.
b. The costliest house is having the 5th category of condition.
c. The 4th category of the condition is having the maximum number of houses.
d. None of the above.

#Ans: d. None of the above.

# %%
plt.xlabel('condition')
plt.ylabel('price')
plt.scatter(house['condition'],house['price'])
